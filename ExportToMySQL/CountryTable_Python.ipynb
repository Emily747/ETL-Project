# %%
import pandas as pd
WorldGDP = "Outputs/WorldGDP.csv"
WorldGDPRaw = pd.read_csv(WorldGDP, encoding="ISO-8859-1")



#eliminate nulls
# WorldGDPRaw["nullG"]=pd.isna(WorldGDPRaw['GDP'])
# WorldGDPDF=WorldGDPRaw.loc[WorldGDPRaw["nullG"]==False]

WorldGDPRaw = WorldGDPRaw.dropna(how='any')
WorldGDPRaw
# Out:
#                          country countryCode           GDP          POP
# 0                    Afghanistan          AF    550.068459   35530081.0
# 1                        Albania          AL   4537.579056    2873457.0
# 2                        Algeria          DZ   4055.247211   41318142.0
# 3                 American Samoa          AS  11394.475297      55641.0
# 4                        Andorra          AD  39146.548836      76965.0
# 5                         Angola          AO   4100.289786   29784193.0
# 8            Antigua and Barbuda          AG  14803.010928     102012.0
# 9                      Argentina          AR  14398.358771   44271041.0
# 10                       Armenia          AM   3936.798320    2930450.0
# 11                         Aruba          AW  25655.102022     105264.0
# 12                     Australia          AU  53793.537256   24601860.0
# 13                       Austria          AT  47380.829637    8797566.0
# 14                    Azerbaijan          AZ   4135.138601    9854033.0
# 15                       Bahamas          BS  30762.012439     395361.0
# 16                       Bahrain          BH  23739.157173    1492584.0
# 17                    Bangladesh          BD   1516.513270  164669751.0
# 18                      Barbados          BB  16356.980110     285719.0
# 19                       Belarus          BY   5733.307210    9498264.0
# 20                       Belgium          BE  43467.445896   11382393.0
# 21                        Belize          BZ   4971.201636     374681.0
# 22                         Benin          BJ    827.393679   11175692.0
# 24                        Bhutan          BT   3130.233543     807610.0
# 25                       Bolivia          BO   3393.955818   11051600.0
# 27        Bosnia and Herzegovina          BA   5148.208517    3507017.0
# 28                      Botswana          BW   7595.611141    2291661.0
# 30                        Brazil          BR   9812.278531  209288278.0
# 32             Brunei Darussalam          BN  28290.585196     428697.0
# 33                      Bulgaria          BG   8228.011570    7075947.0
# 34                  Burkina Faso          BF    642.037148   19193382.0
# 35                       Burundi          BI    292.005210   10864245.0
# ..                           ...         ...           ...          ...
# 207                        Spain          ES  28208.300405   46593171.0
# 208                    Sri Lanka          LK   4073.736519   21444000.0
# 209                        Sudan          SD   2898.549346   40533330.0
# 210                     Suriname          SR   5317.389539     563402.0
# 212                    Swaziland          SZ   3242.751065    1367254.0
# 213                       Sweden          SE  53253.476641   10057698.0
# 214                  Switzerland          CH  80342.846338    8450851.0
# 217                   Tajikistan          TJ    801.050871    8921343.0
# 218  United Republic of Tanzania          TZ    958.445683   57310019.0
# 219                     Thailand          TH   6595.004125   69037513.0
# 220                  Timor-Leste          TL   2279.253204    1296311.0
# 221                         Togo          TG    610.151730    7797694.0
# 223                        Tonga          TO   3959.079757     108020.0
# 224          Trinidad and Tobago          TT  16126.370950    1369125.0
# 225                      Tunisia          TN   3464.416890   11532127.0
# 226                       Turkey          TR  10546.152563   80745020.0
# 227                 Turkmenistan          TM   6586.625863    5758075.0
# 229                       Tuvalu          TV   3549.974741      11192.0
# 230                       Uganda          UG    606.468453   42862958.0
# 231                      Ukraine          UA   2639.824326   44831135.0
# 232         United Arab Emirates          AE  40698.849336    9400145.0
# 233               United Kingdom          GB  39953.573056   66023290.0
# 234                United States          US  59927.930286  325147121.0
# 236                      Uruguay          UY  16245.598368    3456750.0
# 237                   Uzbekistan          UZ   1533.852038   32387200.0
# 238                      Vanuatu          VU   3123.614591     276244.0
# 240                     Viet Nam          VN   2342.244003   95540800.0
# 245                        Yemen          YE   1106.803906   28250420.0
# 246                       Zambia          ZM   1513.276316   17094130.0
# 247                     Zimbabwe          ZW   1333.395663   16529904.0
#
# [192 rows x 4 columns]

# %%
Wine = "Resources/winedata.csv"
WineDF = pd.read_csv(Wine, encoding="ISO-8859-1")
WineDF.reset_index(inplace=True)
WineDF = WineDF.dropna(how='any')
WineDF
# Out:
#        index      country  points  price           province  \
# 0          0     Portugal      87   15.0              Douro
# 1          1           US      87   14.0             Oregon
# 2          2           US      87   65.0             Oregon
# 3          3        Spain      87   15.0     Northern Spain
# 4          4        Italy      87   16.0  Sicily & Sardinia
# 5          5       France      87   24.0             Alsace
# 6          6       France      87   27.0             Alsace
# 7          7           US      87   19.0         California
# 8          8       France      87   30.0             Alsace
# 9          9           US      87   34.0         California
# 10        10           US      87   12.0         California
# 11        11    Argentina      87   30.0              Other
# 12        12    Argentina      87   13.0   Mendoza Province
# 13        13        Spain      87   28.0     Northern Spain
# 14        14           US      87   20.0             Oregon
# 15        15        Italy      87   19.0  Sicily & Sardinia
# 16        16           US      87   22.0         California
# 17        17        Italy      87   35.0  Sicily & Sardinia
# 18        18           US      87   69.0         California
# 19        19        Italy      87   13.0  Sicily & Sardinia
# 20        20        Italy      87   10.0  Sicily & Sardinia
# 21        21        Italy      87   17.0  Sicily & Sardinia
# 22        22           US      86   16.0         California
# 23        23           US      86   50.0             Oregon
# 24        24        Chile      86   15.0   Colchagua Valley
# 25        25           US      86   22.0             Oregon
# 26        26       France      86    9.0         Beaujolais
# 27        27        Chile      86    9.0       Maule Valley
# 28        28       France      86   14.0         Beaujolais
# 29        29        Chile      85   22.0   Colchagua Valley
# ...      ...          ...     ...    ...                ...
# 91470  91470      Austria      91   32.0            Kamptal
# 91471  91471    Argentina      91   25.0   Mendoza Province
# 91472  91472      Austria      91   70.0         Burgenland
# 91473  91473           US      90   20.0         California
# 91474  91474           US      90   35.0         California
# 91475  91475        Italy      90   29.0  Sicily & Sardinia
# 91476  91476       Israel      90   25.0            Galilee
# 91477  91477           US      90   20.0         California
# 91478  91478        Italy      90   20.0  Sicily & Sardinia
# 91479  91479    Argentina      90   43.0              Other
# 91480  91480           US      90   35.0         California
# 91481  91481           US      90   35.0         California
# 91482  91482       France      90   30.0             Alsace
# 91483  91483           US      90   22.0         California
# 91484  91484  New Zealand      90   25.0        Hawke's Bay
# 91485  91485  New Zealand      90   15.0        Marlborough
# 91486  91486  New Zealand      90   40.0        Marlborough
# 91487  91487  New Zealand      90   19.0        Hawke's Bay
# 91488  91488        Spain      90   17.0     Northern Spain
# 91489  91489  New Zealand      90   35.0        Hawke's Bay
# 91490  91490       France      90   57.0             Alsace
# 91491  91491     Portugal      90   48.0              Douro
# 91492  91492        Italy      90   30.0  Sicily & Sardinia
# 91493  91493        Italy      90   40.0  Sicily & Sardinia
# 91494  91494       Israel      90   20.0            Galilee
# 91495  91495       France      90   28.0             Alsace
# 91496  91496           US      90   75.0             Oregon
# 91497  91497       France      90   30.0             Alsace
# 91498  91498       France      90   32.0             Alsace
# 91499  91499       France      90   21.0             Alsace
#
#              taster_name taster_twitter_handle  \
# 0             Roger Voss            @vossroger
# 1           Paul Gregutt          @paulgwineÂ
# 2           Paul Gregutt          @paulgwineÂ
# 3      Michael Schachner           @wineschach
# 4        Kerin OâKeefe          @kerinokeefe
# 5             Roger Voss            @vossroger
# 6             Roger Voss            @vossroger
# 7         Virginie Boone               @vboone
# 8             Roger Voss            @vossroger
# 9         Virginie Boone               @vboone
# 10         Matt Kettmann         @mattkettmann
# 11     Michael Schachner           @wineschach
# 12     Michael Schachner           @wineschach
# 13     Michael Schachner           @wineschach
# 14          Paul Gregutt          @paulgwineÂ
# 15       Kerin OâKeefe          @kerinokeefe
# 16         Matt Kettmann         @mattkettmann
# 17       Kerin OâKeefe          @kerinokeefe
# 18        Virginie Boone               @vboone
# 19       Kerin OâKeefe          @kerinokeefe
# 20       Kerin OâKeefe          @kerinokeefe
# 21       Kerin OâKeefe          @kerinokeefe
# 22        Virginie Boone               @vboone
# 23          Paul Gregutt          @paulgwineÂ
# 24     Michael Schachner           @wineschach
# 25          Paul Gregutt          @paulgwineÂ
# 26            Roger Voss            @vossroger
# 27     Michael Schachner           @wineschach
# 28            Roger Voss            @vossroger
# 29     Michael Schachner           @wineschach
# ...                  ...                   ...
# 91470         Roger Voss            @vossroger
# 91471  Michael Schachner           @wineschach
# 91472         Roger Voss            @vossroger
# 91473     Virginie Boone               @vboone
# 91474     Virginie Boone               @vboone
# 91475    Kerin OâKeefe          @kerinokeefe
# 91476      Mike DeSimone        @worldwineguys
# 91477      Matt Kettmann         @mattkettmann
# 91478    Kerin OâKeefe          @kerinokeefe
# 91479  Michael Schachner           @wineschach
# 91480     Virginie Boone               @vboone
# 91481     Virginie Boone               @vboone
# 91482         Roger Voss            @vossroger
# 91483     Virginie Boone               @vboone
# 91484     Joe Czerwinski                @JoeCz
# 91485     Joe Czerwinski                @JoeCz
# 91486     Joe Czerwinski                @JoeCz
# 91487     Joe Czerwinski                @JoeCz
# 91488  Michael Schachner           @wineschach
# 91489     Joe Czerwinski                @JoeCz
# 91490         Roger Voss            @vossroger
# 91491         Roger Voss            @vossroger
# 91492    Kerin OâKeefe          @kerinokeefe
# 91493    Kerin OâKeefe          @kerinokeefe
# 91494      Mike DeSimone        @worldwineguys
# 91495         Roger Voss            @vossroger
# 91496       Paul Gregutt          @paulgwineÂ
# 91497         Roger Voss            @vossroger
# 91498         Roger Voss            @vossroger
# 91499         Roger Voss            @vossroger
#
#                                                    title  \
# 0          Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1          Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2      Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 3      Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# 4       Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 5                  Trimbach 2012 Gewurztraminer (Alsace)
# 6      Jean-Baptiste Adam 2012 Les Natures Pinot Gris...
# 7      Kirkland Signature 2011 Mountain CuvÃ©e Cabern...
# 8                Leon Beyer 2012 Gewurztraminer (Alsace)
# 9      Louis M. Martini 2012 Cabernet Sauvignon (Alex...
# 10              Mirassou 2012 Chardonnay (Central Coast)
# 11            Felix Lavaque 2010 Felix Malbec (Cafayate)
# 12     Gaucho Andino 2011 Winemaker Selection Malbec ...
# 13     Pradorey 2010 Vendimia Seleccionada Finca Vald...
# 14                      Acrobat 2013 Pinot Noir (Oregon)
# 15     Baglio di Pianetto 2007 Ficiligno White (Sicilia)
# 16     Bianchi 2011 Signature Selection Merlot (Paso ...
# 17          CanicattÃ¬ 2009 Aynat Nero d'Avola (Sicilia)
# 18     Castello di Amorosa 2011 King Ridge Vineyard P...
# 19          Stemmari 2013 Dalila White (Terre Siciliane)
# 20          Stemmari 2013 Nero d'Avola (Terre Siciliane)
# 21     Terre di Giurfo 2011 Mascaria Barricato  (Cera...
# 22     Clarksburg Wine Company 2010 Chenin Blanc (Cla...
# 23            Erath 2010 Hyland Pinot Noir (McMinnville)
# 24     Estampa 2011 Estate Viognier-Chardonnay (Colch...
# 25     Hawkins Cellars 2009 Pinot Noir (Willamette Va...
# 26                Henry Fessy 2012 Nouveau  (Beaujolais)
# 27                   Sundance 2011 Merlot (Maule Valley)
# 28     Vignerons de Bel Air 2011 EtÃ© Indien  (Brouilly)
# 29     Casa Silva 2008 Gran Reserva Petit Verdot (Col...
# ...                                                  ...
# 91470  BrÃ¼ndlmayer 2007 Langenloiser Berg-Vogelsang ...
# 91471       Chakana 2006 Reserve Malbec (LujÃ¡n de Cuyo)
# 91472  Schloss Halbturn 2004 Grand Vin White (Burgenl...
# 91473         Apriori 2013 Chardonnay (Mendocino County)
# 91474   Arrowood 2010 Cabernet Sauvignon (Sonoma County)
# 91475  Baglio del Cristo di Campobello 2012 AdÃ¨nzia ...
# 91476  Barkan 2011 Special Reserve Winemakers' Choice...
# 91477  Birichino 2013 Jurassic Park Vineyard Old Vine...
# 91478  Feudo Principi di Butera 2012 Symposio Red (Te...
# 91479    Finca Las Moras 2010 Pedernal Malbec (San Juan)
# 91480  Flora Springs 2013 Barrel Fermented Chardonnay...
# 91481  Hendry 2012 Blocks 7 & 22 Zinfandel (Napa Valley)
# 91482  Henri Schoenheitz 2012 Holder Gewurztraminer (...
# 91483             Houdini 2011 Zinfandel (Chiles Valley)
# 91484  Mills Reef 2011 Elspeth Cabernet Merlot (Hawke...
# 91485    Ara 2013 Single Estate Pinot Gris (Marlborough)
# 91486            Dog Point 2012 Chardonnay (Marlborough)
# 91487  Esk Valley 2011 Gimblett Gravels Merlot-Cabern...
# 91488          ViÃ±edos Real Rubio 2010 Crianza  (Rioja)
# 91489             Babich 2010 Irongate Red (Hawke's Bay)
# 91490  Cave de Turckheim 2010 Brand Grand Cru Pinot G...
# 91491  Caves Transmontanas 2006 VÃ©rtice Pinot Noir (...
# 91492                        COS 2013 Frappato (Sicilia)
# 91493  Cusumano 2012 SÃ gana Tenuta San Giacomo Nero ...
# 91494  Dalton 2012 Oak Aged Cabernet Sauvignon (Galilee)
# 91495  Domaine RieflÃ©-Landmann 2013 Seppi Landmann V...
# 91496                  Citation 2004 Pinot Noir (Oregon)
# 91497  Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 91498      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 91499  Domaine Schoffit 2012 Lieu-dit Harth CuvÃ©e Ca...
#
#                         variety
# 0                Portuguese Red
# 1                    Pinot Gris
# 2                    Pinot Noir
# 3            Tempranillo-Merlot
# 4                      Frappato
# 5               GewÃ¼rztraminer
# 6                    Pinot Gris
# 7            Cabernet Sauvignon
# 8               GewÃ¼rztraminer
# 9            Cabernet Sauvignon
# 10                   Chardonnay
# 11                       Malbec
# 12                       Malbec
# 13            Tempranillo Blend
# 14                   Pinot Noir
# 15                  White Blend
# 16                       Merlot
# 17                 Nero d'Avola
# 18                   Pinot Noir
# 19                  White Blend
# 20                 Nero d'Avola
# 21                    Red Blend
# 22                 Chenin Blanc
# 23                   Pinot Noir
# 24          Viognier-Chardonnay
# 25                   Pinot Noir
# 26                        Gamay
# 27                       Merlot
# 28                        Gamay
# 29                 Petit Verdot
# ...                         ...
# 91470         GrÃ¼ner Veltliner
# 91471                    Malbec
# 91472               White Blend
# 91473                Chardonnay
# 91474        Cabernet Sauvignon
# 91475                 Red Blend
# 91476                    Shiraz
# 91477              Chenin Blanc
# 91478                 Red Blend
# 91479                    Malbec
# 91480                Chardonnay
# 91481                 Zinfandel
# 91482           GewÃ¼rztraminer
# 91483                 Zinfandel
# 91484           Cabernet Merlot
# 91485                Pinot Gris
# 91486                Chardonnay
# 91487  Bordeaux-style Red Blend
# 91488         Tempranillo Blend
# 91489  Bordeaux-style Red Blend
# 91490                Pinot Gris
# 91491                Pinot Noir
# 91492                  Frappato
# 91493              Nero d'Avola
# 91494        Cabernet Sauvignon
# 91495                Pinot Gris
# 91496                Pinot Noir
# 91497           GewÃ¼rztraminer
# 91498                Pinot Gris
# 91499           GewÃ¼rztraminer
#
# [91500 rows x 9 columns]

# %%
GroupByDF = WineDF.groupby(['country']) #this only indicates what to group by we have to select after
distinctCountry=GroupByDF.count() # returns the mean of all columns grouped by the column we chose. we have to do this to have a new dataframe to perform calcs
distinctCountry.reset_index(inplace=True)

WineCountryDF=distinctCountry[["country"]]
WineCountryDF.head()
# Out:
#                   country
# 0               Argentina
# 1                 Armenia
# 2               Australia
# 3                 Austria
# 4  Bosnia and Herzegovina

# %%
# left join
CountryTable = pd.merge(WineCountryDF, WorldGDPRaw, on="country", how="left")
CountryTable.reset_index(inplace=True)
CountryTable["countryId"] = CountryTable["index"]+1
CountryTable.head()
# Out:
#    index                 country countryCode           GDP         POP  \
# 0      0               Argentina          AR  14398.358771  44271041.0
# 1      1                 Armenia          AM   3936.798320   2930450.0
# 2      2               Australia          AU  53793.537256  24601860.0
# 3      3                 Austria          AT  47380.829637   8797566.0
# 4      4  Bosnia and Herzegovina          BA   5148.208517   3507017.0
#
#    countryId
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5

# %%
CountryTable.to_csv("Outputs/CountryTable.csv", index=False)

# %% [markdown]
# Insert into My sql database

# %%
import pandas as pd
ImportTable = "Outputs/CountryTable.csv"
CountryTable = pd.read_csv(ImportTable, encoding="ISO-8859-1")

CountryToExport=CountryTable[["countryId","country","countryCode","GDP","POP"]]
CountryToExport.head()
# Out:
#    countryId                 country countryCode           GDP         POP
# 0          1               Argentina          AR  14398.358771  44271041.0
# 1          2                 Armenia          AM   3936.798320   2930450.0
# 2          3               Australia          AU  53793.537256  24601860.0
# 3          4                 Austria          AT  47380.829637   8797566.0
# 4          5  Bosnia and Herzegovina          BA   5148.208517   3507017.0

# %%
from sqlalchemy import create_engine

# %%
rds_connection_string = "root:Sanangel1@127.0.0.1/Wine_Ratings"
engine = create_engine(f'mysql+pymysql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['country', 'state', 'taster', 'wine']

# %%
CountryToExport.to_sql(name='country', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     233             sql += v
# --> 234         rows += self.execute(sql + postfix)
#     235         self.rowcount = rows
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '1' for key 'PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-10-3ca438debb56> in <module>
# ----> 1 CountryToExport.to_sql(name='country', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1125                          schema=schema, dtype=dtype)
#    1126         table.create()
# -> 1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#    1129             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pandas\io\sql.py in insert(self, chunksize)
#     639
#     640                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 641                 self._execute_insert(conn, keys, chunk_iter)
#     642
#     643     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     614     def _execute_insert(self, conn, keys, data_iter):
#     615         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 616         conn.execute(self.insert_statement(), data)
#     617
#     618     def insert(self, chunksize=None):
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1168                         statement,
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#    1172                 if self.dialect._has_events:
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     103
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#     107             context._rowcount = rowcount
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     195             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#     199         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     232                 sql += b','
#     233             sql += v
# --> 234         rows += self.execute(sql + postfix)
#     235         self.rowcount = rows
#     236         return rows
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '1' for key 'PRIMARY'") [SQL: 'INSERT INTO country (`countryId`, country, `countryCode`, `GDP`, `POP`) VALUES (%(countryId)s, %(country)s, %(countryCode)s, %(GDP)s, %(POP)s)'] [parameters: ({'countryId': 1, 'country': 'Argentina', 'countryCode': 'AR', 'GDP': 14398.358770905501, 'POP': 44271041.0}, {'countryId': 2, 'country': 'Armenia', 'countryCode': 'AM', 'GDP': 3936.7983196528703, 'POP': 2930450.0}, {'countryId': 3, 'country': 'Australia', 'countryCode': 'AU', 'GDP': 53793.5372560884, 'POP': 24601860.0}, {'countryId': 4, 'country': 'Austria', 'countryCode': 'AT', 'GDP': 47380.8296365373, 'POP': 8797566.0}, {'countryId': 5, 'country': 'Bosnia and Herzegovina', 'countryCode': 'BA', 'GDP': 5148.208516959389, 'POP': 3507017.0}, {'countryId': 6, 'country': 'Brazil', 'countryCode': 'BR', 'GDP': 9812.27853101845, 'POP': 209288278.0}, {'countryId': 7, 'country': 'Bulgaria', 'countryCode': 'BG', 'GDP': 8228.011569726501, 'POP': 7075947.0}, {'countryId': 8, 'country': 'Canada', 'countryCode': 'CA', 'GDP': 44870.7761570967, 'POP': 36708083.0}  ... displaying 10 of 41 total bound parameter sets ...  {'countryId': 40, 'country': 'Ukraine', 'countryCode': 'UA', 'GDP': 2639.82432586795, 'POP': 44831135.0}, {'countryId': 41, 'country': 'Uruguay', 'countryCode': 'UY', 'GDP': 16245.598367743101, 'POP': 3456750.0})] (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
pd.read_sql_query('select * from country', con=engine).head()
# Out:
#    countryId                 country countryCode       GDP         POP
# 0          1               Argentina          AR  14398.36  44271041.0
# 1          2                 Armenia          AM   3936.80   2930450.0
# 2          3               Australia          AU  53793.54  24601860.0
# 3          4                 Austria          AT  47380.83   8797566.0
# 4          5  Bosnia and Herzegovina          BA   5148.21   3507017.0
